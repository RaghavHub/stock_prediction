# %%
import json;
from pprint import pprint

# %%
with open('news_0000001.json') as f:
    data = json.load(f)

# %%
content = data['text']
print(content)
# Out:
# Privacy Policy Amazon.com, Inc. (NasdaqGS:AMZN) FCF Score & Quant Update
# The FCF Yield 5yr Average is calculated by taking the five year average free cash flow of a company, and dividing it by the current enterprise value. Enterprise Value is calculated by taking the market capitalization plus debt, minority interest and preferred shares, minus total cash and cash equivalents. The average FCF of a company is determined by looking at the cash generated by operations of the company. The Free Cash Flow Yield 5 Year Average of Amazon.com, Inc. (NasdaqGS:AMZN) is 0.004663.
# ...

# %%
import os;
